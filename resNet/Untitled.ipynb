# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
import torch.nn.init as init

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

transform_train = transforms.Compose(
    [transforms.RandomCrop(32),
     transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
     normalize])
transform_test = transforms.Compose(
    [transforms.RandomCrop(32),
     transforms.ToTensor(),
     normalize])

trainset = torchvision.datasets.CIFAR10(root='../data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=768,
                                          shuffle=True, num_workers=2, pin_memory=True)

testset = torchvision.datasets.CIFAR10(root='../data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=512,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

import matplotlib.pyplot as plt
import numpy as np

def _weights_init(m):
    classname = m.__class__.__name__
    #print(classname)
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

class basicBlock(nn.Module):
    def __init__(self, inChannel, outChannel, stride = 1):
        super(basicBlock, self).__init__()
        self.conv_t = nn.Conv2d(inChannel, outChannel, kernel_size=3, stride = stride, padding = 1, bias=False)
        self.conv_m = nn.Conv2d(outChannel, outChannel, kernel_size=3, stride = 1, padding = 1, bias=False)
        self.bn1                 = nn.BatchNorm2d(outChannel)
        self.bn2                 = nn.BatchNorm2d(outChannel)
        self.reDem = nn.Sequential()
        # re demension
        if stride != 1 or inChannel != outChannel:
            self.reDem = nn.Sequential(nn.Conv2d(inChannel, outChannel, kernel_size=1, stride = 2, bias=False),nn.BatchNorm2d(outChannel))
    def forward(self, x):
        out = self.bn2(self.conv_m(F.relu(self.bn1(self.conv_t(x)))))
        # residual addiction
        out = self.reDem(x) + out
        # relu result
        out = F.relu(out)
        return out
        
class resNet(nn.Module):
    def __init__(self):
        super(resNet, self).__init__()
        self.inChannel = 16
        self.conv0 = nn.Conv2d(3, 16, kernel_size=3, padding = 1, bias=False)
        self.bn0   = nn.BatchNorm2d(16)
    
        self.layer1 = self._make_layer(9, 16, 1)
        self.layer2 = self._make_layer(9, 32, 2)
        self.layer3 = self._make_layer(9, 64, 2)
        self.avg_pool = nn.AvgPool2d(8, stride = 1)
        self.linear = nn.Linear(64, 10)
        self.fc = nn.Linear(8*8, 10)
        
        self.apply(_weights_init)
    
    def _make_layer(self, numBlocks, channel,  stride):
        strides = [stride] + [1]*(numBlocks -1)
        layers = []
        for stride in strides :
            layers.append(basicBlock(self.inChannel, channel, stride))
            self.inChannel = channel
        return nn.Sequential(*layers)
    
    def forward(self, x):
        #conv0 224 -> 56
        x = F.relu(self.bn0(self.conv0(x)))
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        x = F.avg_pool2d(x, x.size()[3])
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x


net = resNet()
print(net)

device = torch.device("cuda:0")
net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay=1e-4)

decay_epoch = [100, 150]
step_lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=decay_epoch, gamma=0.1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# resNet(
#   (conv0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (1): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (2): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (3): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (4): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (5): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (6): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (7): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (8): basicBlock(
#       (conv_t): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): basicBlock(
#       (conv_t): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (2): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (3): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (4): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (5): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (6): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (7): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (8): basicBlock(
#       (conv_t): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): basicBlock(
#       (conv_t): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (2): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (3): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (4): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (5): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (6): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (7): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#     (8): basicBlock(
#       (conv_t): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv_m): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (reDem): Sequential()
#     )
#   )
#   (avg_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#   (linear): Linear(in_features=64, out_features=10, bias=True)
#   (fc): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
summary(net,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#             Conv2d-3           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-4           [-1, 16, 32, 32]              32
#             Conv2d-5           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-6           [-1, 16, 32, 32]              32
#         basicBlock-7           [-1, 16, 32, 32]               0
#             Conv2d-8           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-9           [-1, 16, 32, 32]              32
#            Conv2d-10           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-11           [-1, 16, 32, 32]              32
#        basicBlock-12           [-1, 16, 32, 32]               0
#            Conv2d-13           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-14           [-1, 16, 32, 32]              32
#            Conv2d-15           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-16           [-1, 16, 32, 32]              32
#        basicBlock-17           [-1, 16, 32, 32]               0
#            Conv2d-18           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-19           [-1, 16, 32, 32]              32
#            Conv2d-20           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-21           [-1, 16, 32, 32]              32
#        basicBlock-22           [-1, 16, 32, 32]               0
#            Conv2d-23           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-24           [-1, 16, 32, 32]              32
#            Conv2d-25           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-26           [-1, 16, 32, 32]              32
#        basicBlock-27           [-1, 16, 32, 32]               0
#            Conv2d-28           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-29           [-1, 16, 32, 32]              32
#            Conv2d-30           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-31           [-1, 16, 32, 32]              32
#        basicBlock-32           [-1, 16, 32, 32]               0
#            Conv2d-33           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-34           [-1, 16, 32, 32]              32
#            Conv2d-35           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-36           [-1, 16, 32, 32]              32
#        basicBlock-37           [-1, 16, 32, 32]               0
#            Conv2d-38           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-39           [-1, 16, 32, 32]              32
#            Conv2d-40           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-41           [-1, 16, 32, 32]              32
#        basicBlock-42           [-1, 16, 32, 32]               0
#            Conv2d-43           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-44           [-1, 16, 32, 32]              32
#            Conv2d-45           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-46           [-1, 16, 32, 32]              32
#        basicBlock-47           [-1, 16, 32, 32]               0
#            Conv2d-48           [-1, 32, 16, 16]           4,608
#       BatchNorm2d-49           [-1, 32, 16, 16]              64
#            Conv2d-50           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-51           [-1, 32, 16, 16]              64
#            Conv2d-52           [-1, 32, 16, 16]             512
#       BatchNorm2d-53           [-1, 32, 16, 16]              64
#        basicBlock-54           [-1, 32, 16, 16]               0
#            Conv2d-55           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-56           [-1, 32, 16, 16]              64
#            Conv2d-57           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-58           [-1, 32, 16, 16]              64
#        basicBlock-59           [-1, 32, 16, 16]               0
#            Conv2d-60           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-61           [-1, 32, 16, 16]              64
#            Conv2d-62           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-63           [-1, 32, 16, 16]              64
#        basicBlock-64           [-1, 32, 16, 16]               0
#            Conv2d-65           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-66           [-1, 32, 16, 16]              64
#            Conv2d-67           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-68           [-1, 32, 16, 16]              64
#        basicBlock-69           [-1, 32, 16, 16]               0
#            Conv2d-70           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-71           [-1, 32, 16, 16]              64
#            Conv2d-72           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-73           [-1, 32, 16, 16]              64
#        basicBlock-74           [-1, 32, 16, 16]               0
#            Conv2d-75           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-76           [-1, 32, 16, 16]              64
#            Conv2d-77           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-78           [-1, 32, 16, 16]              64
#        basicBlock-79           [-1, 32, 16, 16]               0
#            Conv2d-80           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-81           [-1, 32, 16, 16]              64
#            Conv2d-82           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-83           [-1, 32, 16, 16]              64
#        basicBlock-84           [-1, 32, 16, 16]               0
#            Conv2d-85           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-86           [-1, 32, 16, 16]              64
#            Conv2d-87           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-88           [-1, 32, 16, 16]              64
#        basicBlock-89           [-1, 32, 16, 16]               0
#            Conv2d-90           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-91           [-1, 32, 16, 16]              64
#            Conv2d-92           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-93           [-1, 32, 16, 16]              64
#        basicBlock-94           [-1, 32, 16, 16]               0
#            Conv2d-95             [-1, 64, 8, 8]          18,432
#       BatchNorm2d-96             [-1, 64, 8, 8]             128
#            Conv2d-97             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-98             [-1, 64, 8, 8]             128
#            Conv2d-99             [-1, 64, 8, 8]           2,048
#      BatchNorm2d-100             [-1, 64, 8, 8]             128
#       basicBlock-101             [-1, 64, 8, 8]               0
#           Conv2d-102             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-103             [-1, 64, 8, 8]             128
#           Conv2d-104             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-105             [-1, 64, 8, 8]             128
#       basicBlock-106             [-1, 64, 8, 8]               0
#           Conv2d-107             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-108             [-1, 64, 8, 8]             128
#           Conv2d-109             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-110             [-1, 64, 8, 8]             128
#       basicBlock-111             [-1, 64, 8, 8]               0
#           Conv2d-112             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-113             [-1, 64, 8, 8]             128
#           Conv2d-114             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-115             [-1, 64, 8, 8]             128
#       basicBlock-116             [-1, 64, 8, 8]               0
#           Conv2d-117             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-118             [-1, 64, 8, 8]             128
#           Conv2d-119             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-120             [-1, 64, 8, 8]             128
#       basicBlock-121             [-1, 64, 8, 8]               0
#           Conv2d-122             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-123             [-1, 64, 8, 8]             128
#           Conv2d-124             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-125             [-1, 64, 8, 8]             128
#       basicBlock-126             [-1, 64, 8, 8]               0
#           Conv2d-127             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-128             [-1, 64, 8, 8]             128
#           Conv2d-129             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-130             [-1, 64, 8, 8]             128
#       basicBlock-131             [-1, 64, 8, 8]               0
#           Conv2d-132             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-133             [-1, 64, 8, 8]             128
#           Conv2d-134             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-135             [-1, 64, 8, 8]             128
#       basicBlock-136             [-1, 64, 8, 8]               0
#           Conv2d-137             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-138             [-1, 64, 8, 8]             128
#           Conv2d-139             [-1, 64, 8, 8]          36,864
#      BatchNorm2d-140             [-1, 64, 8, 8]             128
#       basicBlock-141             [-1, 64, 8, 8]               0
#           Linear-142                   [-1, 10]             650
# ================================================================
# Total params: 855,770
# Trainable params: 855,770
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 10.28
# Params size (MB): 3.26
# Estimated Total Size (MB): 13.56
# ----------------------------------------------------------------

# %%
print('hing')
for epoch in range(200):
    net.train()
    running_loss = 0.0
    #print(epoch)
    for i, data in enumerate(trainloader, 0):
        # [inputs, labels]의 목록인 data로부터 입력을 받은 후;
        inputs, labels = data[0].to(device), data[1].to(device)
        #print(i)
        # 변화도(Gradient) 매개변수를 0으로 만들고
        

        # 순전파 + 역전파 + 최적화를 한 후
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 통계를 출력합니다.
        running_loss += loss.item()
                  
    step_lr_scheduler.step()
    print('epoch : %5d loss : %.7f' %(epoch + 1, (running_loss / 65)))
    
    correct = 0
    total = 0
    #net.eval()
    with torch.no_grad():
        for data in testloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))
# Out:
# hing
# epoch :     1 loss : 2.3622616
# Accuracy of the network on the 10000 test images: 30 %
# epoch :     2 loss : 1.7049124
# Accuracy of the network on the 10000 test images: 38 %
# epoch :     3 loss : 1.5172529
# Accuracy of the network on the 10000 test images: 46 %
# epoch :     4 loss : 1.3388647
# Accuracy of the network on the 10000 test images: 54 %
# epoch :     5 loss : 1.1812409
# Accuracy of the network on the 10000 test images: 56 %
# epoch :     6 loss : 1.0507733
# Accuracy of the network on the 10000 test images: 64 %
# epoch :     7 loss : 0.9092663
# Accuracy of the network on the 10000 test images: 67 %
# epoch :     8 loss : 0.8185395
# Accuracy of the network on the 10000 test images: 72 %
# epoch :     9 loss : 0.7241904
# Accuracy of the network on the 10000 test images: 73 %
# epoch :    10 loss : 0.6596391
# Accuracy of the network on the 10000 test images: 75 %
# epoch :    11 loss : 0.6036499
# Accuracy of the network on the 10000 test images: 75 %
# epoch :    12 loss : 0.5625653
# Accuracy of the network on the 10000 test images: 78 %
# epoch :    13 loss : 0.5172225
# Accuracy of the network on the 10000 test images: 79 %
# epoch :    14 loss : 0.4807169
# Accuracy of the network on the 10000 test images: 79 %
# epoch :    15 loss : 0.4395760
# Accuracy of the network on the 10000 test images: 79 %
# epoch :    16 loss : 0.4128352
# Accuracy of the network on the 10000 test images: 80 %
# epoch :    17 loss : 0.3809473
# Accuracy of the network on the 10000 test images: 80 %
# epoch :    18 loss : 0.3623930
# Accuracy of the network on the 10000 test images: 80 %
# epoch :    19 loss : 0.3680355
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    20 loss : 0.3178374
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    21 loss : 0.3061601
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    22 loss : 0.2752540
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    23 loss : 0.2713228
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    24 loss : 0.2646581
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    25 loss : 0.2251694
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    26 loss : 0.2228387
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    27 loss : 0.2110816
# Accuracy of the network on the 10000 test images: 81 %
# epoch :    28 loss : 0.2138100
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    29 loss : 0.1936818
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    30 loss : 0.2680967
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    31 loss : 0.1776261
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    32 loss : 0.1676904
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    33 loss : 0.1459053
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    34 loss : 0.1541489
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    35 loss : 0.1366347
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    36 loss : 0.1420959
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    37 loss : 0.1135045
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    38 loss : 0.1117437
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    39 loss : 0.1301536
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    40 loss : 0.1027502
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    41 loss : 0.1725915
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    42 loss : 0.1258051
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    43 loss : 0.1025511
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    44 loss : 0.0954898
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    45 loss : 0.0968044
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    46 loss : 0.1125914
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    47 loss : 0.0815575
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    48 loss : 0.0752752
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    49 loss : 0.0511157
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    50 loss : 0.0608989
# Accuracy of the network on the 10000 test images: 82 %
# epoch :    51 loss : 0.0640629
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    52 loss : 0.0495304
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    53 loss : 0.0851731
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    54 loss : 0.1389593
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    55 loss : 0.0616527
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    56 loss : 0.1007534
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    57 loss : 0.0622017
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    58 loss : 0.0416928
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    59 loss : 0.0659180
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    60 loss : 0.0631807
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    61 loss : 0.0506247
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    62 loss : 0.0666810
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    63 loss : 0.0599716
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    64 loss : 0.0809471
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    65 loss : 0.0470389
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    66 loss : 0.0295025
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    67 loss : 0.0320022
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    68 loss : 0.0277579
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    69 loss : 0.0412331
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    70 loss : 0.0433417
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    71 loss : 0.0779317
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    72 loss : 0.0587496
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    73 loss : 0.0399579
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    74 loss : 0.0366459
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    75 loss : 0.0671037
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    76 loss : 0.0344821
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    77 loss : 0.0649450
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    78 loss : 0.0575015
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    79 loss : 0.0351452
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    80 loss : 0.0229645
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    81 loss : 0.0516089
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    82 loss : 0.0600780
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    83 loss : 0.0437327
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    84 loss : 0.0373278
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    85 loss : 0.0500647
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    86 loss : 0.0548295
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    87 loss : 0.0484682
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    88 loss : 0.0546495
# Accuracy of the network on the 10000 test images: 83 %
# epoch :    89 loss : 0.0506191
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    90 loss : 0.0503161
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    91 loss : 0.0728960
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    92 loss : 0.0373602
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    93 loss : 0.0307639
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    94 loss : 0.0228248
# Accuracy of the network on the 10000 test images: 84 %
# epoch :    95 loss : 0.0153981
# Accuracy of the network on the 10000 test images: 85 %
# epoch :    96 loss : 0.0087213
# Accuracy of the network on the 10000 test images: 85 %
# epoch :    97 loss : 0.0078420
# Accuracy of the network on the 10000 test images: 85 %
# epoch :    98 loss : 0.0041554
# Accuracy of the network on the 10000 test images: 85 %
# epoch :    99 loss : 0.0036703
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   100 loss : 0.0132893
# Accuracy of the network on the 10000 test images: 84 %
# epoch :   101 loss : 0.0072576
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   102 loss : 0.0027904
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   103 loss : 0.0017058
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   104 loss : 0.0014967
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   105 loss : 0.0014843
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   106 loss : 0.0014108
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   107 loss : 0.0013698
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   108 loss : 0.0011367
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   109 loss : 0.0010009
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   110 loss : 0.0011220
# Accuracy of the network on the 10000 test images: 86 %
# epoch :   111 loss : 0.0010460
# Accuracy of the network on the 10000 test images: 86 %
# epoch :   112 loss : 0.0009354
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   113 loss : 0.0008547
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   114 loss : 0.0012655
# Accuracy of the network on the 10000 test images: 86 %
# epoch :   115 loss : 0.0008478
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   116 loss : 0.0007811
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   117 loss : 0.0007412
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   118 loss : 0.0006643
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   119 loss : 0.0006785
# Accuracy of the network on the 10000 test images: 86 %
# epoch :   120 loss : 0.0006552
# Accuracy of the network on the 10000 test images: 86 %
# epoch :   121 loss : 0.0007758
# Accuracy of the network on the 10000 test images: 86 %
# epoch :   122 loss : 0.0006390
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   123 loss : 0.0009174
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   124 loss : 0.0014406
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   125 loss : 0.0009492
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   126 loss : 0.0007447
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   127 loss : 0.0010225
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   128 loss : 0.0006733
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   129 loss : 0.0006108
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   130 loss : 0.0007243
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   131 loss : 0.0008755
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   132 loss : 0.0006891
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   133 loss : 0.0006286
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   134 loss : 0.0007034
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   135 loss : 0.0005360
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   136 loss : 0.0006136
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   137 loss : 0.0005028
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   138 loss : 0.0013236
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   139 loss : 0.0008135
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   140 loss : 0.0007102
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   141 loss : 0.0006373
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   142 loss : 0.0011575
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   143 loss : 0.0007862
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   144 loss : 0.0006582
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   145 loss : 0.0008530
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   146 loss : 0.0008264
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   147 loss : 0.0007784
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   148 loss : 0.0007013
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   149 loss : 0.0005629
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   150 loss : 0.0006012
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   151 loss : 0.0005340
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   152 loss : 0.0005218
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   153 loss : 0.0004846
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   154 loss : 0.0006744
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   155 loss : 0.0007591
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   156 loss : 0.0005372
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   157 loss : 0.0004908
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   158 loss : 0.0005755
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   159 loss : 0.0005027
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   160 loss : 0.0005943
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   161 loss : 0.0006016
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   162 loss : 0.0005099
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   163 loss : 0.0004979
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   164 loss : 0.0005758
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   165 loss : 0.0004724
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   166 loss : 0.0004964
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   167 loss : 0.0006357
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   168 loss : 0.0005000
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   169 loss : 0.0004787
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   170 loss : 0.0005101
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   171 loss : 0.0004838
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   172 loss : 0.0004631
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   173 loss : 0.0004764
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   174 loss : 0.0004525
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   175 loss : 0.0004504
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   176 loss : 0.0005204
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   177 loss : 0.0006410
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   178 loss : 0.0006624
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   179 loss : 0.0004987
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   180 loss : 0.0008649
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   181 loss : 0.0006667
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   182 loss : 0.0010082
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   183 loss : 0.0005289
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   184 loss : 0.0004526
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   185 loss : 0.0004665
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   186 loss : 0.0005238
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   187 loss : 0.0005346
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   188 loss : 0.0005054
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   189 loss : 0.0004825
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   190 loss : 0.0008061
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   191 loss : 0.0004416
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   192 loss : 0.0005391
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   193 loss : 0.0005480
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   194 loss : 0.0004324
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   195 loss : 0.0004599
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   196 loss : 0.0007287
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   197 loss : 0.0004579
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   198 loss : 0.0004434
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   199 loss : 0.0005041
# Accuracy of the network on the 10000 test images: 85 %
# epoch :   200 loss : 0.0004502
# Accuracy of the network on the 10000 test images: 85 %

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 85 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels =  data[0].to(device), data[1].to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 85 %
# Accuracy of   cat : 66 %
# Accuracy of  deer : 71 %
# Accuracy of   dog : 66 %
# Accuracy of  frog : 54 %
# Accuracy of horse : 83 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 100 %

# %%
PATH = '../model/resNetCIFAR10nobias.pth'
torch.save(net.state_dict(), PATH)
